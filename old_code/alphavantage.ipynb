# %%
import os
import pandas as pd
import requests
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AMZN&interval=5min&month=2001-01&outputsize=full&apikey=' + os.environ['ALPHAVANTAGE_KEY']
# r = requests.get(url)
# data = r.json()

# %%
# print(data['Time Series (5min)'])
# df = pd.DataFrame.from_dict(data['Time Series (5min)'], orient='index')
# df
# Out:
#                     1. open 2. high  3. low 4. close 5. volume
# 2001-01-31 18:15:00  0.8720  0.8720  0.8720   0.8720     24000
# 2001-01-31 18:10:00  0.8690  0.8690  0.8630   0.8630     36000
# 2001-01-31 18:00:00  0.8700  0.8700  0.8700   0.8700     10000
# 2001-01-31 17:40:00  0.8690  0.8690  0.8690   0.8690     36000
# 2001-01-31 17:25:00  0.8660  0.8660  0.8660   0.8660      8000
# ...                     ...     ...     ...      ...       ...
# 2001-01-02 08:25:00  0.7880  0.7870  0.7880   0.7880     10000
# 2001-01-02 08:20:00  0.8030  0.8030  0.8030   0.8030     20000
# 2001-01-02 08:10:00  0.8000  0.8030  0.8000   0.8030     12000
# 2001-01-02 08:05:00  0.8030  0.8030  0.8030   0.8030     10000
# 2001-01-02 08:00:00  0.8130  0.8120  0.8030   0.8030     42000
#
# [2328 rows x 5 columns]

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&time_from=20000410T0130&limit=1000&apikey=' + os.environ['ALPHAVANTAGE_KEY']
r = requests.get(url)
data = r.json()

# %%
data
# Out:
# {'items': '691',
#  'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish',
#  'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.',
#  'feed': [{'title': 'Apple Glass, Potential Competitor To Ray-Ban Meta Smart Glasses, May Take Longer To Develop: Report - Meta Platforms  ( NASDAQ:META ) ',
#    'url': 'https://www.benzinga.com/news/24/06/39449125/apple-glass-potential-competitor-to-ray-ban-meta-smart-glasses-may-take-longer-to-develop-report',
#    'time_published': '20240624T031236',
#    'authors': ['Ananya Gairola'],
#    'summary': 'Apple Inc.\'s AAPL much-anticipated "Apple Glass," rumored competitor to Meta Platforms Inc.\'s META Ray-Ban smart glasses, may not hit the market for several more years.',
# ...

# %%
import pandas as pd

df = pd.DataFrame.from_dict(data, orient='columns')
df
# Out:
#     items                         sentiment_score_definition  \
# 0     691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 1     691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 2     691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 3     691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 4     691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# ..    ...                                                ...
# 686   691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 687   691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 688   691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 689   691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 690   691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
#
#                             relevance_score_definition  \
# 0    0 < x <= 1, with a higher score indicating hig...
# 1    0 < x <= 1, with a higher score indicating hig...
# 2    0 < x <= 1, with a higher score indicating hig...
# ...

# %%
df_expanded = pd.concat([df.drop(['feed'], axis=1), pd.json_normalize(df['feed'])], axis=1)

# %%
df_expanded
# Out:
#     items                         sentiment_score_definition  \
# 0     691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 1     691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 2     691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 3     691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 4     691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# ..    ...                                                ...
# 686   691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 687   691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 688   691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 689   691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 690   691  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
#
#                             relevance_score_definition  \
# 0    0 < x <= 1, with a higher score indicating hig...
# 1    0 < x <= 1, with a higher score indicating hig...
# 2    0 < x <= 1, with a higher score indicating hig...
# ...

# %%
for file in os.listdir("company_news"):
    news = pd.read_csv("company_news/" + file)
    news['datetime'] = pd.to_datetime(news['datetime'], unit='s')
    news.to_csv('company_news/' + file, index=False)

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AMZN&time_from=20220410T0130&time_to=20230410T0130&limit=1000&apikey=' + os.environ['ALPHAVANTAGE_KEY']
r = requests.get(url)
data = r.json()
df = pd.DataFrame.from_dict(data)
df_expanded = pd.concat([df.drop(['feed'], axis=1), pd.json_normalize(df['feed'])], axis=1)
df_expanded
# Out:
#     items                         sentiment_score_definition  \
# 0     727  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 1     727  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 2     727  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 3     727  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 4     727  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# ..    ...                                                ...
# 722   727  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 723   727  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 724   727  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 725   727  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 726   727  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
#
#                             relevance_score_definition  \
# 0    0 < x <= 1, with a higher score indicating hig...
# 1    0 < x <= 1, with a higher score indicating hig...
# 2    0 < x <= 1, with a higher score indicating hig...
# ...

# %%
data
# Out:
# {'Information': 'No articles found. Please adjust the time range or refer to the API documentation https://www.alphavantage.co/documentation#newsapi and try again.'}
